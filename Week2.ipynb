# %% [markdown]
# <a href="https://colab.research.google.com/github/ifaindrianningsih/PCVK_Genap-2023/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB) # konversi channel BGR -> RGB
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#simpan File image
#cv.imwrite('/content/drive/MyDrive/PCVK/',imgs)

#tampilkan plot dengan ukuran canvas yg lebih besar
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) #nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yg mewakili R,G,dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# TUGAS

# %% [markdown]
# 2.	Tampilkan image dalam channel Red-Blue dan Green-Blue saja!

# %%
# Red - Blue
plt.imshow(img_gray, cmap='RdBu')

# %%
# Green - Blue
plt.imshow(img_gray, cmap='GnBu')

# %% [markdown]
# 3.	Tampilkan image baris ke 20-115, kolom 25-120!

# %%
img_rb = img3[20:115,25:120]
plt.imshow(img_rb)

# %% [markdown]
# 4.	Tampilkan image baris ke 5-30, semua kolom, channel Red saja!

# %%
plt.imshow(img_gray[5:30], cmap="Reds")

# %% [markdown]
# 5.	Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image. Disarankan menggunakan bilangan acak/random!

# %%
img5 = cv.cvtColor(img,cv.COLOR_BGR2RGB)

cv.rectangle(img5, pt1=(100,0), pt2=(40,30), color=(0,255,0), thickness=3)
cv.rectangle(img5, pt1=(90,70), pt2=(120,90), color=(255,0,0), thickness=3)
cv.rectangle(img5, pt1=(50,70), pt2=(80,90), color=(0,0,255), thickness=3)
cv.rectangle(img5, pt1=(100,50), pt2=(80,40), color=(100,120,0), thickness=3)
cv.rectangle(img5, pt1=(50,70), pt2=(23,84), color=(0,100,210), thickness=3)

plt.imshow(img5)

# %% [markdown]
# 6.	Tampilkan image dengan posisi terbalik!

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#simpan File image
#cv.imwrite('/content/drive/MyDrive/PCVK/',imgs)

#tampilkan plot dengan ukuran canvas yg lebih besar
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %% [markdown]
# 7.	Buat rectangle dan circle pada bagian wajah dari image foto anda saat beraktifitas (bukan pasfoto).

# %%
photo = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg')

photo = cv.cvtColor(photo, cv.COLOR_BGR2RGB)

cv.rectangle(photo, pt1=(100, 86), pt2=(189, 9), color=(255, 0, 0), thickness=2)

cv.circle(photo, center=(147, 45), radius=45, color=(0, 255, 0), thickness=2)

plt.imshow(photo)

# %% [markdown]
# 8.	Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB dari citra kitten/ lena/ mandrill/ male/ female/ couple/ sailboat/ peppers!

# %%
photo1 = cv.imread('/content/drive/MyDrive/PCVK/kitten01.jpg')
photo1_rgb = cv.cvtColor(photo1, cv.COLOR_BGR2RGB)
cv.rectangle(photo1_rgb,pt1=(10,175),pt2=(50,100),color=(255,0,0),thickness=3)
plt.imshow(photo1_rgb)

# %% [markdown]
# 9.	Lengkapi tulisan nama file pada file citra dari soal no.8. gunakan font, ukuran font, dan warna font yang sesuai keinginan anda.

# %%
photo_rgb = cv.cvtColor(photo1, cv.COLOR_BGR2RGB)
cv.rectangle(photo_rgb,pt1=(10,175),pt2=(50,100),color=(255,0,0),thickness=3)
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(photo_rgb,text='kitten01.jpg',org=(100,155),fontFace=font,fontScale=1,color=(0,0,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(photo_rgb)
